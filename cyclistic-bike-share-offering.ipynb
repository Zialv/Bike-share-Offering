# %% [markdown]
# ![Black and Green Illustrated Bicycle Product![Mobile note list-cuate.png](attachment:e8ebec2b-43e4-4fb7-9bbd-5f90fbdf66d1.png) Presentation.jpg](attachment:35065b95-0949-4dce-8241-5490d1183898.jpg)

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#intro">Executive Summary</a></li>
# <li><a href="#data">Data Information</a></li>
# <li><a href="#eda">Process Data For Analysis</a></li>
# <li><a href="#analysis">Analysis</a></li>
# <li><a href="#results">Analysis Results Summarization</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# <div style="background-color:#FCEDCD; padding: 15px;">
# <h1 style="background-color:#FFD700; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">
# Executive Summary</h1>
# <h2 style="font-size:20px"><b>Company Background:</b></h2>
# <p style="font-size:14px">Cyclistic is a bike-share company operating in Chicago, providing bicycles for short-term rental to customers.</p>
# <h2 style="font-size:20px"><b>Customer Segmentation</b></h2>
#     <ul style="font-size:14px">
#         <li><b>Casual riders</b>: Customers who purchase single-ride or full-day passes</li>
#         <li><b>Cylistc members</b>: Customers who purchase annual memberships</li>
#     </ul>
# <h2 style="font-size:20px"><b>Situation:</b></h2>
# <p style="font-size:14px">Cyclistic’s finance analysts have concluded that annual members are much more profitable
# than casual riders.
# The company believes that maximizing the number of annual members will be key to future growth.
# Rather than creating a marketing campaign that targets all-new customers, Cyclistic believes
# there is a solid opportunity to convert casual riders into members.</p>
# <h2 style="font-size:20px"><b>Key Stakeholders:</b></h2>
#     <ul style="font-size:14px">
#         <li><b>Lily Moreno:</b> The director of marketing who is responsible for developing campaigns and initiatives to promote the bike-sharing program.</li>
#         <li><b>Cyclistic marketing analytics team:</b> This team is responsible for collecting, analyzing, and reporting data that guides Cyclistic's marketing strategy.</li>
#         <li><b>Cyclistic's executive team:</b> This detail-oriented executive team will decide whether to approve the recommended marketing program.</li>
#     </ul>
# <h2 style="font-size:20px"><b>Key Questions:</b></h2>
# <p style="font-size:14px">The analysis will aim to answer the following key questions:</p>
#     <ul style="font-size:14px">
#         <li>How do annual members and casual riders use Cyclistic bikes differently?</li>
#         <li>What are the patterns or behaviors unique to casual riders that could potentially be addressed by a targeted marketing campaign?</li>
#         <li>What are the trends over time for these two user groups? Are there seasonal patterns that could inform the timing of the marketing campaign?</li>
#     </ul>
# <h2 style="font-size:20px"><b>Problem Statement:</b></h2>
# <p style="font-size:14px">To convert casual customer to annual member we will  finding differences in the usage patterns of Cyclistic bikes between casual riders and annual members to design a new marketing strategy.</p>
# </div>

# %% [markdown]
# <a id='data'></a>
# <center><img src='https://img.freepik.com/free-vector/internet-day-concept-illustration_114360-5303.jpg?t=st=1713610629~exp=1713611229~hmac=1ecaf3f037f7c128fec8b3655d7834644abc26333b96cb7b811ba929427de19c' height=200px width=600px></center>
#
# <h1 style="background-color:#FFD700; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;"> Data Information</h1>
# <h2 style="font-size:20px"><b>Data Context</b></h2>
#     <p style="font-size:14px">Our data is from Cyclistic's historical trip records. This data is about two main types of users: casual riders and annual members. The company collects data on bike rides, including ride duration, start and end stations, and user type. The objective is to analyze this data to uncover differences in usage patterns between casual riders and annual members. By understanding these patterns, the marketing team aims to design a new strategy to convert casual riders into annual members, ultimately maximizing annual memberships and enhancing Cyclistic's success in the bike-share market.</p>
# <h2 style="font-size:20px"><b>Timeframe</b></h2>
#     <p style="font-size:14px">The dataset comprises ride data collected by Cyclistic from April 2020 to February 2024</p>
# <h2 style="font-size:20px"><b>Data Location</b></h2>
#     <p style="font-size:14px">The data for this case study is provided by Motivate International Inc and is publicly available for download</p>
# <h2 style="font-size:20px"><b>Data Organization</b></h2>
#     <p style="font-size:14px">The data for this case study is structured in a CSV format, making it easily accessible and manageable for analysis. Each row in the CSV file represents a distinct bike trip, while columns delineate specific attributes such as trip duration, start and end times, start and end stations, bike type, and user type (casual or member).</p>
# <h2 style="font-size:20px"><b>Licensing, Privacy, Security, and Accessibility:</b></h2>
#     <p style="font-size:14px">
# The data has been provided under a specific license, which permits its use for analysis but prohibits sharing the data as a standalone dataset. Privacy is preserved as no personally identifiable information is included in the data. Security will involve storing the downloaded data in a secure location, perhaps encrypted if needed. Accessibility refers to ensuring that the data and the subsequent analysis are available to all stakeholders involved in the project.
# </p>
# <h2 style="font-size:20px"><b>Data Credibility and Bias:</b></h2>
#     <p style="font-size:14px">As the data is provided by the company that operates the bike-sharing service, it should be reliable. However, we must be aware that the data could contain biases </p>
#         <ul style="font-size:14px">
#             <li><b>Selection Bias:</b> Acknowledge that the data only includes individuals who have chosen to use the Cyclistic service. This may introduce selection bias, as the dataset may not represent the entire population of bike riders in Chicago.</li>
#             <li><b>Operational Constraints:</b>Operational constraints or data collection methods within Cyclistic's system could influence the recorded data. For example, factors such as station locations, bike availability, and promotional activities may impact user behavior and usage patterns, potentially biasing the data.</li>
#             <li><b>Temporal Bias:</b> The dataset spans from April 2020 to February 2024, during which various temporal factors could influence bike-sharing usage patterns. Changes in seasons, weather conditions, public events, or transportation infrastructure developments may introduce temporal bias into the data.</li>
#             <li><b>Geographical Bias: </b>The distribution of bike stations across different neighborhoods or regions within Chicago may result in geographical bias. Areas with denser station coverage may attract more riders and consequently have higher representation in the dataset compared to areas with fewer stations.</li>
#            <li><b>Promotional Bias:</b> Promotional campaigns or incentives offered by Cyclistic could impact user behavior and usage patterns recorded in the data. Discounts, promotions, or special events targeting specific user segments may lead to biased usage patterns during promotional periods.</li>
#      <p style="font-size:14px">Understanding and being aware of all biases will help us: Enhanced Credibility,  Improved Accuracy, Better Decision-Making, Increased Transparency, Reduced Risk.</p>
#         </ul>
# <h2 style="font-size:20px"><b>Data Integrity</b></h2>
#     <p style="font-size:14px">To verify data's integrity we can follow these methods:</p>
#         <ul style="font-size:14px">
#             <li><b>Source Verification:</b> Verify the source of the data to ensure it comes from a reputable and reliable provider. This may involve checking the credibility of the organization or individual supplying the data and reviewing any documentation or certifications they provide.</li>
#             <li><b>Data Quality Checks:</b> Conduct thorough checks for data completeness, consistency, accuracy, and timeliness. Look for missing values, outliers, duplicates, and inconsistencies within the dataset by performing exploratory data analysis (EDA).</li>
#             <li><b>Documentation Review:</b> Review any documentation provided with the dataset, such as data dictionaries, metadata, or data collection methodologies. Understanding how the data was collected, processed, and maintained can provide insights into its integrity. (This cyclistic's dataset doesn't have any document)</li>
#             <li><b>Data Sampling:</b> Conduct random or systematic sampling of the dataset to assess its representativeness and reliability. Sampling allows you to evaluate the quality of the data without analyzing the entire dataset.</li>
#             <li><b>Relevance to the Business Question:</b> The data contains information on bike trips by both casual riders and annual members, which is directly relevant to the business question of understanding how the two types of users utilize the Cyclistic bikes differently. By analyzing patterns and trends in the data, you can extract insights to inform a marketing strategy aimed at converting casual riders into annual members.</li>
#         </ul>
# <h2 style="font-size:20px"><b>Data Problems and Limitations</b></h2>
#     <p style="font-size:14px"> Potential problems could include missing data, errors in the data, or bias in the data.</p>
#     <p style="font-size:14px"> Data limitation is lacks direct demographic data of users such as age, gender, or socioeconomic status.</p>

# %% [markdown]
# <center><img src='https://img.freepik.com/premium-vector/illustration-vector-graphic-cartoon-character-data-analysis_516790-990.jpg' height=200px width=600px></center>
#
# <h1 style="background-color:#FFD700; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;"> Process Data for Analysis</h1>

# %% [markdown]
# <h3>📚 Importing Libaries & Dataset</h3>

# %%
import numpy as np 
import pandas as pd 
import os
from math import radians, cos, sin, sqrt, atan2
# Importing Visualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as px
import plotly.offline as pyo 
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots

# Import the warnings module to suppress unnecessary warnings.
import warnings

# %% [markdown]
# <h2 style="color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">1. Cleaning Process </h2>

# %% [markdown]
# <div style="font-size:20px; background-color:#DAF4F6; padding: 20px;">
# The process will follow these steps:
#     <ol>
#         <li>Checking and fixing data types:</li>
#         <li>Correcting inconsistent text and typos:</li>
#         <li>Addressing missing values:</li>
#         <li>Checking for duplicates:</li>
#         <li>Excluding irrelevant rows and columns</li>

# %%
allpaths = [] # List to get all directory 
dataframes = [] # List to store all dataframes
for dirpath, _, filenames in os.walk('/kaggle/input'):
    for file in filenames:
        # Create full path for filename:
        fullpath = os.path.join(dirpath,file)
        # Append full path to the list of allpaths 
        allpaths.append(fullpath)
for file in allpaths:
    if file.endswith('.csv'): #to ensure we're working with csv
        #print('procesing file',file) #keep track of progress
        df = pd.read_csv(file)
        dataframes.append(df)
# Now, i am concating all dataframes because they have same schema ( same columns) 
trip_data = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# <h3>📚 Fixing Datatype </h3>

# %% [markdown]
# <div style="background-color:#DAF4F6; padding: 15px;">
# <p style="font-size:20px">After running trip_data.dtypes, we determined the type of each column in the dataset. We concluded that 'started_at' and 'ended_at' should be datetime objects, while 'start_station_id,' 'start_station_name,' 'end_station_id,' and 'end_station_name' should be treated as categorical data (strings). <p>

# %%
#Convert to datetime
trip_data['started_at'] = pd.to_datetime(trip_data['started_at'])
trip_data['ended_at'] = pd.to_datetime(trip_data['ended_at'])

# %%
#Convert to str
trip_data['start_station_name'] = np.where(trip_data['start_station_name'].isna(),trip_data['start_station_name'],trip_data['start_station_name'].astype(str))
trip_data['start_station_id'] = np.where(trip_data['start_station_id'].isna(),trip_data['start_station_id'],trip_data['start_station_id'].astype(str))
trip_data['end_station_name'] = np.where(trip_data['end_station_name'].isna(), trip_data['end_station_name'],trip_data['end_station_name'].astype(str))
trip_data['end_station_id'] = np.where(trip_data['end_station_id'].isna(), trip_data['end_station_id'],trip_data['end_station_id'].astype(str))

# %% [markdown]
# <h3>📚 Fixing inconsistent text & typos </h3>

# %%
start_station = trip_data.loc[:,('start_station_name','start_station_id')]
end_station = trip_data.loc[:,('end_station_name','end_station_id')]
columns_map = {'start_station_name':'station_name','start_station_id':'station_id',
               'end_station_name':'station_name', 'end_station_id':'station_id'}
start_station.rename(columns=columns_map,inplace=True)
end_station.rename(columns=columns_map,inplace=True)
lookup_tbl = pd.concat([start_station,end_station],ignore_index=True)
lookup_tbl.dropna(inplace=True)
del start_station
del end_station

# %%
def create_dict(df, column1, column2):
    # Decide to choose the most frequent column2' values to be the main values
    # Count the frequency of column2' values group by column 1.
    # Then create a dictionary include all most frequent column2' value for column 1 
    dict_1 = df.groupby(column1)[column2].apply(lambda x:x.value_counts().idxmax()).to_dict()
    # Create a new column in data frame, map this data frame to above dictionary by column 1
    df['new_column'] = df[column1].map(dict_1)
    # Make column 2 = new_column
    df[column2] = df['new_column']
    # Then drop new_column 
    df = df.drop(columns=['new_column'])
    # Create dictionary 
    df.drop_duplicates(inplace=True)
    df.set_index(column1,inplace=True)
    dict_2 = df.to_dict()
    dict_3 = dict_2[column2]
    return dict_3

# %%
station_id_dict = create_dict(lookup_tbl,'station_name','station_id')
station_name_dict = create_dict(lookup_tbl,'station_id', 'station_name')

# %%
# Update start station
trip_data['start_station_id'] = trip_data['start_station_name'].map(station_id_dict).combine_first(trip_data['start_station_id'])
trip_data['start_station_name'] = trip_data['start_station_id'].map(station_name_dict).combine_first(trip_data['start_station_name'])

# %%
# Update end station
trip_data['end_station_id'] = trip_data['end_station_name'].map(station_id_dict).combine_first(trip_data['end_station_id'])
trip_data['end_station_name'] = trip_data['end_station_id'].map(station_name_dict).combine_first(trip_data['end_station_name'])

# %% [markdown]
# <h3>📚 Fixing Missing Values </h3>

# %% [markdown]
# <h4>❗Fill Missing Values</h4>

# %%
# Filling missing value in station name by 'Unknown'
trip_data['start_station_name'] = trip_data['start_station_name'].fillna('Unknown')
trip_data['start_station_id'] = trip_data['start_station_id'].fillna('Unknown')
trip_data['end_station_name'] = trip_data['end_station_name'].fillna('Unknown')
trip_data['end_station_id'] = trip_data['end_station_id'].fillna('Unknown')

# %% [markdown]
# <h4>❗Drop Missing Values</h4>

# %%
trip_data.dropna(inplace=True)

# %% [markdown]
# <h3>📚 Check Duplicates </h3>

# %%
#trip_data[trip_data.duplicated()]
# NO dupplicate

# %% [markdown]
# <h3>📚 Drop irrelevent columns </h3>

# %%
trip_data = trip_data.drop(columns=['ride_id','start_station_id','end_station_id'])

# %% [markdown]
# <h3>📚 Drop irrelevent values (rows) </h3>

# %%
# Remove station outside of chicago 
chicago_bbox = {
    'min_lat': 41.6446,
    'max_lat': 42.023,
    'min_lon': -87.9401,
    'max_lon': -87.5249
}
trip_data = trip_data[(trip_data['start_lat'] >= chicago_bbox['min_lat']) & (trip_data['start_lat'] <= chicago_bbox['max_lat']) &
        (trip_data['start_lng'] >= chicago_bbox['min_lon']) & (trip_data['start_lng'] <= chicago_bbox['max_lon']) &
        (trip_data['end_lat'] >= chicago_bbox['min_lat']) & (trip_data['end_lat'] <= chicago_bbox['max_lat']) &
        (trip_data['end_lng'] >= chicago_bbox['min_lon']) & (trip_data['end_lng'] <= chicago_bbox['max_lon'])]

# %% [markdown]
# <h2 style="color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">2. Creating New Columns </h2>

# %% [markdown]
# <div style="background-color:#DAF4F6; padding: 20px;">
# <h3 style="font-size:20px; font-family:verdana;"><b>Feature Engineering: </b></h3>
# <p style="font-size:14px; font-family:verdana; line-height: 1.7em">Feature engineering is an essential step in the data analysis process. It involves creating new features or modifying existing ones to improve the performance of machine learning models or to reveal new insights from the data. For our dataset, we will be creating several new features based on the start and end times of the bike rides, as well as their geographical coordinates:</p>
#     <ul style="font-size:14px; font-family:verdana; line-height: 1.7em">
#         <li><b>ride_length</b>: This will be the length of the ride in minutes, hours.</li>
#         <li><b>day_of_week</b>: This will be the day of the week the ride started, with Monday=1 and Sunday=7. This could reveal trends about which days of the week see the most bike rides.</li>
#         <li><b>hour</b>: This is the hour of the day when the ride started, which can help us understand usage patterns across different times of the day.</li>
#         <li><b>month</b>: This is the month when the ride started, which can help us understand usage patterns across different months.</li>
#         <li><b>year</b>: This is the year when the ride started, which can help us understand usage patterns across different years.</li>
#         <li><b>distance_km</b>: This will be the geographical distance between the start and end points of the ride, calculated using the Haversine formula.</li>
#         <li><b>length_lables, ride_length_category</b> and <b>distance_category</b>: These are categorical representations of the ride length and distance respectively, based on predefined bins. They could be useful for examining distributions and trends across different ranges of ride lengths and distances.</li>
#     </ul>
# <p style="font-size:14px; font-family:verdana; line-height: 1.7em">Let's now proceed to add these features to our dataframe.</p>
# </div>

# %% [markdown]
# <div style="background-color:#F8F5D5; padding: 20px;">
#     <h2 style="font-size:20px"><b>Create a function to cacualate ride_length</b></h2>
#         <ul style="font-size:14px">
#         <li>This will be the length of the ride in minutes, hours and be cacualted by subtracting end time from start time.</li>
#         <li>After caculation, we decide to drop all record have time less than 1 minutes (As 1 minutes is too short for a ride)</li>
#         </ul>
# </div>

# %%
def create_ride_length_feat(df):
    # Create ride_length in hours:
    df['no_of_hours'] = (df['ended_at'] - df['started_at']).abs().dt.total_seconds() / 3600
    #Create ride_length in minutes: 
    df['no_of_minutes'] = (df['ended_at'] - df['started_at']).abs().dt.total_seconds() / 60
    df = df[df['no_of_minutes'] > 1]
    return df

# %% [markdown]
# <div style="background-color:#F8F5D5; padding: 20px;">
#     <h2 style="font-size:20px"><b>Create a function to retrieve hour, date, month, year from start time column</b></h2>
# </div>

# %%
def create_time_feat(df): 
    # Create Hour column
    df['hour'] = df['started_at'].dt.hour
    # Create day of week column
    df['day_of_week'] = df['started_at'].dt.dayofweek + 1 #Monday = 0 in default 
    # Create month column 
    df['month'] = df['started_at'].dt.month 
    # Create year column 
    df['year'] = df['started_at'].dt.year
    return df

# %% [markdown]
# <div style="background-color:#F8F5D5; padding: 20px;">
#     <h2 style="font-size:20px"><b>Create a function to cacualate distance</b></h2>
#         <ul style="font-size:14px">
#             <li>The Haversine formula calculates the distance between two points on the Earth's surface given their coordinates. It takes into account the Earth's curvature to provide an accurate distance.</li>
#             <li>This feature is only relative because the longitude and latitude of the starting and ending points do not represent the exact distance the customer has cycled.</li>
#             <li>We create a function to cacualte the distance of start and end points based on longtitude and latitude. </li>
#             <li>However, there are cases where customers start and end at the same station, resulting in a calculated distance of zero. In such instances, we will replace zero distances with the average distance traveled by casual or member customers, depending on the customer type.</li>
#         </ul>
# </div>

# %%
def calculate_distance(row):
    # Radius of the earth in km
    R = 6371.0

    lat1 = np.radians(row['start_lat'])
    lon1 = np.radians(row['start_lng'])
    lat2 = np.radians(row['end_lat'])
    lon2 = np.radians(row['end_lng'])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    # Convert to kilometers
    distance = R * c

    return distance
# # Calculate the distance
# trip_data['distance_km'] = trip_data.apply(calculate_distance, axis=1)

# %%
def create_distance_feat(df):
        # Calculate the distance
    df['distance_km'] = calculate_distance(trip_data)
    filtered_df = df[df['distance_km'] != 0]
    mean_casual = filtered_df.groupby('member_casual')['distance_km'].mean().get(key='casual')
    mean_member = filtered_df.groupby('member_casual')['distance_km'].mean().get(key='member')
    df['distance_km'] = np.where((df['member_casual'] == 'member') & (df['distance_km'] == 0), mean_member, df['distance_km'])
    df['distance_km'] = np.where((df['member_casual'] == 'casual') & (df['distance_km'] == 0), mean_casual, df['distance_km'])
    return df

# %% [markdown]
# <div style="background-color:#F8F5D5; padding: 20px;">
#     <h2 style="font-size:20px"><b>Create length_lables, ride_length_category and distance_category</b></h2>
# </div>

# %%
def create_category_feat(df):
    # Create length labels
    df['duration_label'] = np.where(df['no_of_hours'] <= 24, 'in day', 'long days')
    # Create Duration Category in Hours
    length_bins = [0, 5, 15, 30, 60, np.inf]
    length_names = ['<5', '<15', '<30', '<60', '60+']
    df['duration_category'] =pd.cut(df['no_of_minutes'], length_bins, labels = length_names)
    # Create distance category 
    bins = [0, 1, 5, 10, np.inf ]
    names = ['<1', '<5', '<10', '10+']
    df['distance category'] = pd.cut(df['distance_km'], bins, labels=names)
    return df

# %% [markdown]
# <div style="background-color:#DAF4F6; padding: 20px;">
# <h3 style="font-size:20px; font-family:verdana;"><b>Apply all above Functions for Trip_data</b></h3>
# </div>

# %%
def create_new_feat(df):
    # Create ride_length
    print('Create ride_length feature')
    ride_length_feat = create_ride_length_feat(df)
    print('===== DONE =====')
    # Create date time 
    print('Create time feature')
    time_feat = create_time_feat(ride_length_feat)
    print('===== DONE =====')
    # Create Distance
    print('Create Distance feature')
    distance_feat = create_distance_feat(time_feat)
    print('===== DONE =====')
    # Create category 
    print('Create category feature')
    category_feat = create_category_feat(distance_feat)
    print('===== DONE =====')
    df = category_feat
    print('===== FINISH =====')
    return df

# %%
# Ignore the warning
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    trip_data = create_new_feat(trip_data)

# %%
trip_data.head()

# %% [markdown]
# <a id='analysis'></a>
# <center><img src='https://img.freepik.com/free-vector/visual-data-concept-illustration_114360-1713.jpg?w=740&t=st=1687494134~exp=1687494734~hmac=6539a4a6faa2e481730cab6dd5bc4d1773176123f59291005f38acbab8d78749' height=200px width=600px></center>
# <h1 style="background-color:#f74f74; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">🕵️‍♀️ The 'Analyze' Phase of the Data Analysis Process</h1>

# %% [markdown]
# <div  style = "font-size:20px">
# To analyze the similarities and differences between members and casual customers, we will analyze the following factors:
#     <ol>
#         <li><b>The distribution of customers:</b></li>
#         Compare the proportion of members and casual customers in the dataset.
#         <li><b>Customer Trends Over Year:</b></li>
#         Examine how the number of members and casual customers changes over the course of the year.
#         <li><b>Rideable Type Distribution:</b></li>
#         Investigate the types of rideables preferred by members and casual customers.
#         <li><b>Hour Distribution:</b></li>
#         Analyze the distribution of bike rides by hour of the day for members and casual customers.
#         <li><b>Station Distribution:</b></li>
#         Explore which stations are most popular among members and casual customers.
#         <li><b>Distance Category Distribution:</b></li>
#         Categorize ride distances and compare their distributions between members and casual customers.
#         <li><b>Duration:</b></li>
#         Compare the duration of bike rides between members and casual customers.
#         <li><b>Month:</b></li>
#         Determine in which months of the year members and casual customers use bikes the most.
#         <li><b>Day of Week:</b></li>
#         Analyze the number of bike rides by day of the week for both groups.
#     </ol>
# By analyzing these factors, we can gain insights into the behavior and preferences of both member and casual customers, allowing for targeted strategies to better serve their needs.
# </div>

# %% [markdown]
# <h1 style="text-align:center; border-radius:15px; font-family:'Verdana', sans-serif"><b>Distribution of Customer</b></h1>

# %%
# Calculate the total number of riders
total_riders = len(trip_data)

# Set up the figure and the two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Bar chart
sns.countplot(x='member_casual', data=trip_data, palette=sns.color_palette("colorblind"), ax=ax[0])
ax[0].set_title('Distribution of Casual and Member Users', fontsize=15)
ax[0].set_xlabel('User Type', fontsize=12)
ax[0].set_ylabel('Count', fontsize=12)

# Add count annotations to the top of the bars
for p in ax[0].patches:
    height = p.get_height()
    ax[0].text(p.get_x()+p.get_width()/2., height + 0.1,
            '{:1.0f}'.format(height), ha="center") 

# Calculate the proportions of casual and member users
user_counts = trip_data['member_casual'].value_counts()

# Donut chart
patches, texts, autotexts = ax[1].pie(user_counts, labels=user_counts.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85, colors=sns.color_palette("colorblind"))

# Draw the center of the pie to create a donut
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax[1].axis('equal')  

# Add the total number of records in the center
label = plt.text(0,0, total_riders, horizontalalignment='center', verticalalignment='center', fontsize=12, weight='bold')

ax[1].set_title(f'Distribution of Casual and Member Users (Total Riders: {total_riders})', fontsize=15)

plt.show()

# %% [markdown]
# <div style="background-color:#F9D25B">
# <h2 style = "font-size:25px">Distribution of Customer Type:</h2>
#     <h3 style = "font-size:20px"><b>User Distribution:</b></h3>
#         <ul style = "font-size:20px">
#             <li>The bar chart illustrates the count of casual and member users, showing that there are more members than casual users.</li>
#             <li>The donut chart provides a visual representation of the proportion of casual and member users, indicating that approximately 59.4% of users are members, while 40.6% are casual users.</li>
#         </ul>
#     <h3 style = "font-size:20px"><b>Analysis:</b></h3>
#         <ul style = "font-size:20px">
#             <li>The higher proportion of members compared to casual users suggests that Cyclistic has successfully attracted a significant number of users to become members, indicating a strong membership base.</li>
#             <li>The relatively smaller proportion of casual users may suggest that Cyclistic could focus more on strategies to attract and retain casual users, such as offering promotions, discounts, or incentives to encourage occasional users to ride more frequently.</li>
#             <li>Additionally, the findings suggest that Cyclistic's membership program is popular among users, potentially indicating that members derive value from the benefits and features offered by the membership.</li>
#         </ul>
# </div>

# %% [markdown]
# <h1 style="text-align:center; border-radius:15px; font-family:'Verdana', sans-serif"><b>Customer Trend</b><h1>

# %%
customer_by_year               = trip_data.loc[:,('year','member_casual')]
customer_count_by_year         = customer_by_year.groupby(['year','member_casual'])['member_casual'].size().reset_index(name='count')
customer_count_by_exclude_2024 = customer_count_by_year[customer_count_by_year['year'] != 2024]
casual_data                    = customer_count_by_exclude_2024[customer_count_by_exclude_2024['member_casual'] == 'casual']
member_data                    = customer_count_by_exclude_2024[customer_count_by_exclude_2024['member_casual'] == 'member']

# Line chart customer over years
plt.figure(figsize=(15,6))
plt.plot(member_data['year'], member_data['count'], label='member')
plt.plot(casual_data['year'], casual_data['count'], label='casual')
plt.xlabel('Year')
plt.ylabel('Customer Count')
plt.title('Member and Casual custome by Year')
# Adding legend
plt.legend()

# Customize x-axis ticks to display only integer years
plt.xticks(range(int(min(customer_count_by_year['year'])), int(max(customer_count_by_year['year'])) + 1));

# %% [markdown]
# <div style="background-color:#F9D25B">
# <h2 style = "font-size:25px">Customer Trend Over Year:</h2>
#     <h3 style = "font-size:20px"><b>Customer trend:</b></h3>
#         <ul style="font-size:20px">
#             <li>The line chart illustrates an upward trend in the number of members over the years, particularly surging from 2020 to 2021. Subsequently, there is a slight continued increase until the conclusion of 2023.</li>
#             <li>Conversely, the count of casual customers demonstrates an increase from 2020 to 2021, followed by a decline from 2021 onwards until the end of 2023.</li>
#         </ul>
#      <h3 style = "font-size:20px"><b>Analysis:</b></h3>
#          <ul style="font-size:20px">
#             <li>The line chart indicates the success of Cylistic's efforts in converting customers into members over time. However, it also suggests that Cylistic hasn't effectively reached out to new customers, as there isn't a significant increase in the overall customer base.</li>
#          </ul>
# </div>

# %% [markdown]
# <h1 style="text-align:center; border-radius:15px; font-family:'Verdana', sans-serif"><b>Rideable Type Distribution</b><h1>

# %%
# Set the figure size
plt.figure(figsize=(10,6))

# Create a custom palette
palette = sns.color_palette("colorblind")

# Create the countplot
sns.countplot(x='rideable_type', hue='member_casual', data=trip_data, palette=palette)

# Customize title and labels
plt.title('Rideable Type Distribution for Casual and Member Users', fontsize=15)
plt.xlabel('Rideable Type', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Customize the legend
plt.legend(title='User Type', title_fontsize='13', loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# <div style="background-color:#F9D25B">
#    <ul style="font-size:20px">
#         <li>The bar chart indicates that classical bikes are most commonly used by member customers</li>
#         <li>Electric bikes are the preferred choice among casual customers</li>
#         <li>Moreover, casual customers tend to use docked bikes more frequently than member customers.</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="text-align:center; border-radius:15px; font-family:'Verdana', sans-serif"><b>Hours Distribution</b><h1>

# %%
def format_hour(h: int):
    h = str(h)
    if len(h) == 1: 
        h = '0'+h
    h = h+ ":00"
    return h


# Group by hour and user type, and count the number of rides
hourly = trip_data.groupby(['hour', 'member_casual'])['start_station_name'].count().reset_index()
hourly.columns =['Hour of Day',"User Type","Number of Rides"]
hourly['Hour of Day'] = hourly['Hour of Day'].apply(format_hour)

fig = px.line_polar(
    data_frame=hourly,
    r = 'Number of Rides',
    theta='Hour of Day',
    color='User Type',
    line_close=True,
    color_discrete_sequence=['crimson', 'royalblue'],
)

fig.update_layout(
    title="Distribution of Rides by Hour of Day", 
    template="seaborn",
    title_x=0.5,
    height=900,
)

fig.show()

# %% [markdown]
# <div style="background-color:#F9D25B">
#   <ul style="font-size:20px">
#         <li>The chart shows that the bike riding time for casual customers is fairly evenly distributed throughout the day, with the peak occurring at 5 PM.</li>
#         <li>Bike riding time for members is distributed more distinctly. The peak riding times for members are at 8 AM, 12 PM, and especially at 5 PM. Members tend to use bikes less during other time frames.</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="text-align:center; border-radius:15px; font-family:'Verdana', sans-serif"><b>Stations Distribution</b><h1>

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
# Exclude "Missing" from the data
filtered_data = trip_data[~trip_data['start_station_name'].isin(['Unknown'])]
# Calculate the top 10 end stations
top_start_stations = filtered_data['start_station_name'].value_counts().head(10).index
# Filter the data to include only the top 10 end stations
top_start_stations_data = filtered_data[filtered_data['start_station_name'].isin(top_start_stations)]
# Create a custom palette
palette = sns.color_palette("colorblind", 10)
# Create the countplot with hue_order
sns.countplot(y='start_station_name', hue='member_casual', hue_order=['member', 'casual'], data=top_start_stations_data, palette=palette, order=top_start_stations)
# Customize title and labels
plt.title('Top 10 Start Stations Distribution for Casual and Member Users', fontsize=15)
plt.xlabel('Count', fontsize=12)
plt.ylabel('start Station Name', fontsize=12)
# Customize the legend
plt.legend(title='User Type', title_fontsize='13', loc='lower right')


plt.subplot(1,2,2)
# Exclude "Other" and "Missing" from the data
filtered_data = trip_data[~trip_data['end_station_name'].isin(['Unknown'])]
# Calculate the top 10 end stations
top_end_stations = filtered_data['end_station_name'].value_counts().head(10).index
# Filter the data to include only the top 10 end stations
top_end_stations_data = filtered_data[filtered_data['end_station_name'].isin(top_end_stations)]
# Create a custom palette
palette = sns.color_palette("colorblind", 10)
# Create the countplot
sns.countplot(y='end_station_name', hue='member_casual',hue_order=['member', 'casual'], data=top_end_stations_data, palette=palette, order=top_end_stations)
# Customize title and labels
plt.title('Top 10 End Stations Distribution for Casual and Member Users', fontsize=15)
plt.xlabel('Count', fontsize=12)
plt.ylabel('End Station Name', fontsize=12)
# Customize the legend
plt.legend(title='User Type', title_fontsize='13', loc='lower right')


plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#F9D25B">
#    <ul style="font-size:20px">
# The <b>Top 10 stations</b> chart indicates that:
#      <li>Casual bike users frequent <b>Streeter Dr & Grand Ave</b> the most.</li>
#      <li>Meanwhile, members use bikes quite evenly across all stations.</li>
#    </ul>
# </div>

# %%
# Define the figure size
plt.figure(figsize=(12, 8))
palette = sns.color_palette("colorblind")
# Create a countplot for the distance_category feature for both casual and member users
sns.countplot(data=trip_data, x='distance category', hue='member_casual', palette=palette)

# Set the title and labels
plt.title('Count of Rides in Each Distance Category for Casual and Member Users', fontsize=15)
plt.xlabel('Distance Category (km)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the legend
plt.legend(title='User Type', title_fontsize='13')

# Show the plot
plt.show()

# %% [markdown]
# <div style="font-size:20px; background-color:#F9D25B">
# Both casual and member customers typically ride bikes for distances of less than 5 kilometers per trip.
# </div>

# %%
# Define the figure size
plt.figure(figsize=(12, 8))
palette = sns.color_palette("colorblind")

sns.countplot(x='duration_category', data=trip_data, hue='member_casual', palette=palette)
# Set the title and labels
plt.title('Count of Rides in Each Duration Category for Casual and Member Users', fontsize=15)
plt.xlabel('Duration Catagory (minutes)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the legend
plt.legend(title='User Type', title_fontsize='13')

# Show the plot
plt.show()

# %% [markdown]
# <div style="font-size:20px; background-color:#F9D25B">
#     <ul>
# Looking at the chart, we can see that:
#         <li>Trips taken by Member customers are primarily under 30 minutes, with the highest frequency occurring around 15 minutes. </li>
#         <li>Similarly, Casual customers also have the highest number of trips around the 15-minute mark.</li>
#         <li>However, Casual customers have more trips lasting around 60 minutes or longer compared to Member customers.</li>
#         <li>Additionally, Casual customers have relatively fewer short trips of around 5 minutes, while Members have a relatively higher number of trips lasting around 5 minutes.</li>
#     </ul>
#    => Member customers prefer shorter trips, whereas casual customers prefer longer trips.
# </div>

# %%
# Define the figure size
plt.figure(figsize=(12, 8))
palette = sns.color_palette("colorblind")

sns.countplot(x='month', data=trip_data, hue='member_casual', palette=palette)
# Set the title and labels
plt.title('Number of trips by Month', fontsize=15)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the legend
plt.legend(title='User Type', title_fontsize='13')

# Show the plot
plt.show()

# %% [markdown]
# <div style="font-size:20px; background-color:#F9D25B">
# Based on the chart, we observe that:
#     <ul>
#         <li>Member customers use the bike service most frequently in August.</li>
#         <li>Casual customers use the bike service most frequently in July.</li>
#         <li>In other months, member usage is lower but relatively consistent. Meanwhile, casual customer usage is consistently lower, with spikes only occurring from May to October.</li>
#     </ul>
# </div>

# %%
# Define the figure size
plt.figure(figsize=(12, 8))
palette = sns.color_palette("colorblind")

sns.countplot(x='day_of_week', data=trip_data, hue='member_casual', palette=palette)
# Set the title and labels
plt.title('Number of trips by Day of Week', fontsize=15)
plt.xlabel('Day of Week', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.xticks(ticks=[0, 1, 2, 3, 4, 5, 6], labels=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Show the legend
plt.legend(title='User Type', title_fontsize='13')

# Show the plot
plt.show()

# %% [markdown]
# <div style="font-size:20px; background-color:#F9D25B">
# The bar chart reveals that:
#     <ul>
#         <li>Member customers utilize the bike service consistently across the days of the week, with the least usage on Sundays.</li>
#         <li>Casual customers use the bike service sparingly during the weekdays but significantly more on weekends, especially on Saturdays.</li>
#     </ul>
# </div>

# %% [markdown]
# <a id='results'></a>
# <center><img src='https://img.freepik.com/premium-vector/illustration-vector-graphic-cartoon-character-stock-market_516790-1536.jpg' height=200px width=600px></center>
# <h1 style="background-color:#C4A5F5; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">🕵️‍♀️ Analysis Results Summarization</h1>

# %% [markdown]
# <div style="font-size:20px">
#     <ol>
#         <li><b>The Distribution Of Customers:</b></li>
#         The analysis reveals:
#             <ul>
#                 <li><b style="color:#6852C7">A larger count of members in comparison to casual users</b>. This disparity indicates Cyclistic's effective ability to draw a substantial number of users into membership</li>
#                 <li>The relatively lower count of casual users might imply a potential area for Cyclistic to concentrate on, perhaps by implementing strategies like promotions, discounts, or incentives to enhance the engagement of occasional users and encourage more frequent rides.</li>
#             </ul>
#         <li><b>Customer Trends Over Year:</b></li>
#            <ul>
#                <li>Over time, Cyclistic has demonstrated <b style="color:#6852C7">success in converting customers into members</b>.</li>
#                <li>There is a <b style="color:#6852C7">lack of effective outreach to new customers</b>, as evidenced by a <b style="color:#6852C7">notable decrease</b> in the overall casual customer.</li>
#            </ul>
#         <li><b>Rideable Type Distribution:</b></li>
#             <ul>
#                 <li>Members favor <b style="color:#6852C7">classic bikes</b> as their primary choice.</li>
#                 <li><b style="color:#6852C7">Electric bikes</b> are the preferred option for casual users.</li>
#                 <li>Casual riders tend to utilize <b style="color:#6852C7">docked bikes</b> more often than members do.</li>
#             </ul>
#         <li><b>Hour Distribution:</b></li>
#         The analysis indicates that:
#             <ul>
#                 <li>Bike riding time for <b style="color:#6852C7">casual customers</b> is fairly <b style="color:#6852C7">evenly spread throughout the day</b>, peaking at 5 PM.</li>
#                <li>Bike riding time for <b style="color:#6852C7">members</b> follows a more distinct pattern, with <b style="color:#6852C7">peaks at 8 AM, 12 PM, and notably at 5 PM</b>. Members' bike usage <b style="color:#6852C7">decreases during other time periods.</b>
#            </ul>
#         <li><b>Station Distribution:</b></li>
#         The analysis indicates that:
#             <ul>
#                 <li><b style="color:#6852C7">Casual customers concentrate their bike service usage at specific locations</b>, such as Streeter Dr & Grand Ave Station.</li>
#                 <li><b style="color:#6852C7">Members evenly distribute their bike service usage</b> across various stations.
#             </ul>
#         <li><b>Distance Category Distribution:</b></li>
#         The analysis shows that:
#             <ul>
#                 <li><b style="color:#6852C7">Both casual and member customers usually ride bikes for distances shorter than 5 kilometers per trip.</b></li>
#             </ul>
#         <li><b>Duration Category Distribution:</b></li>
#             <ul>
#                 <li><b style="color:#6852C7">Trips taken by members are primarily under 30 minutes</b>, with the most common duration being 15 minutes per trip.</li>
#                 <li><b style="color:#6852C7">Casual trips mainly last for 15 minutes</b>; however, casual riders tend to take <b style="color:#6852C7">longer trips (over 30 minutes) more frequently compared to members.</b></li>
#             </ul>
#         <li><b>Month:</b></li>
#             <ul>
#                 <li><b style="color:#6852C7">Member customers ride bikes consistently throughout the year</b>, but the highest usage occurs from June to October.</li>
#                 <li><b style="color:#6852C7">Casual customers ride bikes more frequently from June to September</b>. During the remaining months, bike usage is relatively low.</li>
#             </ul>
#         <li><b>Day of Week:</b></li>
#             <ul>
#                 <li><b style="color:#6852C7">Member customers</b> use the bike service <b style="color:#6852C7">consistently every day of the week</b>, with the <b style="color:#6852C7">highest usage on weekdays</b> and lower usage on weekends.</li>
#                 <li><b style="color:#6852C7">Casual customers</b> use the bike service <b style="color:#6852C7">less on weekdays</b> and <b style="color:#6852C7">the most on weekends</b>.</li>
#             </ul>
#     </ol>
# </div>

# %% [markdown]
# <a id='conclusions'></a>
# <center><img src='https://fastwork.vn/wp-content/uploads/2020/01/stock-giai-phap-2-1024x812.png' height=200px width=600px></center>
# <h1 style="background-color:#1DEDAB; color:#000; font-size:32px; padding:20px; text-align:center; border-radius:15px; font-family:'Verdana', sans-serif;">🕵️‍♀️ Conclusions</h1>

# %% [markdown]
# <h1> Answer Key Questions</h1>
# <div style="font-size:20px">
#     <ol>
#         <li><b>How do annual members and casual riders use Cyclistic bikes differently?</b></li>
#             <ul>
#                 <li>Members typically prefer classic bikes, while casual users opt for electric and docked bikes.</li>
#                 <li>Members tend to ride bikes at specific hours (8 AM, 12 PM, and 5 PM), while casual users ride more evenly throughout the day.</li>
#                 <li>Members use bike stations evenly across all locations, whereas casual users tend to frequent specific popular points.</li>
#                 <li>Members usually take trips under 30 minutes, whereas casual users often have longer rides (over 30 minutes).</li>
#                 <li>Members consistently utilize bike services every day, with the highest usage occurring on weekends. Conversely, casual users utilize bikes the most on weekends.</li>
#                 <li>Members consistently utilize bike services every month, whereas casual users use bikes most frequently from June to September.</li>
#             </ul>
#         <li><b>What are the patterns or behaviors unique to casual riders that could potentially be addressed by a targeted marketing campaign?</b></li>
#             <ul>
#                 <li>Casual users concentrate their bike station usage at popular locations, providing Cyclistic's marketing team with valuable insights for setting up marketing campaigns based on these areas.</li>
#                 <li>Since casual customers prefer electric bikes, Cyclistic can offer promotions on electric bikes to encourage casual users to become members.</li>
#                 <li>Given casual users' interest in long trips (over 30 minutes), the company can provide promotions and competitive pricing for extended rides.</li>
#             </ul>
#         <li><b>What are the trends over time for these two user groups? Are there seasonal patterns that could inform the timing of the marketing campaign?</b></li>
#             <ul>
#                 <li>Intensify advertising efforts from June to September and on weekends, as this is when casual customers utilize the service the most.</li>
#             </ul>
#     </ol>
# </div>
#
# <h1>Other Findings</h1>
# <div style="font-size:20px">
#     <ul>
#         <li>The number of member customers steadily increases each year, while casual customers decline. The company should conduct further analysis to devise additional strategies to attract casual customers.</li>
#         <li>The personality traits of casual customers being analyzed closely resemble those of tourists (<b>utilizing the service heavily during peak months, on weekends, and at some popular stations,...</b>). Is it possible that the company's casual customers are primarily tourists? We should conduct further analysis to gain a better understanding. If they are indeed tourists, then attempting marketing strategies to convert current casual customers into members may not be appropriate.</li>
#     </ul>
# </div>
